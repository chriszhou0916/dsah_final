# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statistics
import matplotlib.pyplot as plt

# %%
import sqlite3 # library for working with sqlite database
conn = sqlite3.connect("/Users/arnoldtao/Documents/HoffmanLab/ClassWork/2019S BME590 DataScience/Final/MIMIC.db") # Create a connection to the on-disk database

# %%
pd.read_sql("SELECT * FROM sqlite_master where type='table'", conn)
# Out:
#      type                name            tbl_name  rootpage  \
# 0   table         CHARTEVENTS         CHARTEVENTS         2
# 1   table  PROCEDUREEVENTS_MV  PROCEDUREEVENTS_MV   9120960
# 2   table             CALLOUT             CALLOUT   9132354
# 3   table               D_CPT               D_CPT   9133903
# 4   table             D_ITEMS             D_ITEMS   9133909
# 5   table          CAREGIVERS          CAREGIVERS   9134171
# 6   table  MICROBIOLOGYEVENTS  MICROBIOLOGYEVENTS   9134246
# 7   table           LABEVENTS           LABEVENTS   9153054
# 8   table      INPUTEVENTS_CV      INPUTEVENTS_CV   9708019
# 9   table          ADMISSIONS          ADMISSIONS  10291267
# 10  table          D_LABITEMS          D_LABITEMS  10294375
# 11  table      DATETIMEEVENTS      DATETIMEEVENTS  10294390
# 12  table       PRESCRIPTIONS       PRESCRIPTIONS  10428841
# 13  table      PROCEDURES_ICD      PROCEDURES_ICD  10605718
# 14  table          NOTEEVENTS          NOTEEVENTS  10608088
# ...

# %%
pd.read_sql("SELECT * FROM CHARTEVENTS LIMIT 5", conn)
# Out:
#   ROW_ID SUBJECT_ID HADM_ID ICUSTAY_ID  ITEMID            CHARTTIME  \
# 0    788         36  165660     241249  223834  2134-05-12 12:00:00
# 1    789         36  165660     241249  223835  2134-05-12 12:00:00
# 2    790         36  165660     241249  224328  2134-05-12 12:00:00
# 3    791         36  165660     241249  224329  2134-05-12 12:00:00
# 4    792         36  165660     241249  224330  2134-05-12 12:00:00
#
#              STORETIME   CGID VALUE VALUENUM VALUEUOM WARNING ERROR  \
# 0  2134-05-12 13:56:00  17525    15       15    L/min       0     0
# 1  2134-05-12 13:56:00  17525   100      100                0     0
# 2  2134-05-12 12:18:00  20823   .37      .37                0     0
# 3  2134-05-12 12:19:00  20823     6        6      min       0     0
# 4  2134-05-12 12:19:00  20823   2.5      2.5                0     0
#
#   RESULTSTATUS STOPPED
# 0
# 1
# 2
# 3
# 4

# %%
subject_id_list = [3057, 29665, 28572, 84071, 14405, 40788, 42071, 29191, 9486, 10677, 31928, 20359, 29774, 746, 338, 24858, 88696, 20937, 23008, 10158]
for x in subject_id_list:
    query_string = "SELECT * FROM chartevents WHERE subject_id="
    query_string = query_string + str(x)
    print(query_string)
    temp_df = pd.read_sql(query_string,conn)
    out_path="/Users/arnoldtao/Documents/HoffmanLab/ClassWork/2019S BME590 DataScience/Final/Data/live_patient_" + str(x) + ".csv"
    print (out_path)
    temp_df.to_csv(out_path,index=None, header=True)
# Out:
# SELECT * FROM chartevents WHERE subject_id=3057
# /Users/arnoldtao/Documents/HoffmanLab/ClassWork/2019S BME590 DataScience/Final/Data/live_patient_3057.csv
# SELECT * FROM chartevents WHERE subject_id=29665
# /Users/arnoldtao/Documents/HoffmanLab/ClassWork/2019S BME590 DataScience/Final/Data/live_patient_29665.csv
# SELECT * FROM chartevents WHERE subject_id=28572
# /Users/arnoldtao/Documents/HoffmanLab/ClassWork/2019S BME590 DataScience/Final/Data/live_patient_28572.csv
# SELECT * FROM chartevents WHERE subject_id=84071
